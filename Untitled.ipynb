# %%
import os

directory = r'C:\Users\femi\soccerdata\data\FBref'
os.chdir(directory)
print(directory)
# Out:
# C:\Users\femi\soccerdata\data\FBref

# %%
import pandas as pd
directory = os.getcwd()  # Get the current working directory
html_files = [file for file in os.listdir(directory) if file.endswith(".html")]


html_files = html_files[1:]

# %%
defense_1718 = pd.read_html('players_Big 5 European Leagues Combined_1718_defense.html')

# %%
defense_1718[0]
# Out:
#      Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                      Rk               Player             Nation
# 0                     1  Patrick van Aanholt             nl NED
# 1                     2       Rolando Aarons            eng ENG
# 2                     3       Rolando Aarons            eng ENG
# 3                     4        Ignazio Abate             it ITA
# 4                     5      Aymen Abdennour             tn TUN
# ...                 ...                  ...                ...
# 2793               2687        Bongani Zungu             za RSA
# 2794               2688       David Zurutuza             es ESP
# 2795               2689        Filip Đuričić             rs SRB
# 2796               2690        Filip Đuričić             rs SRB
# 2797               2691    Christian Rutjens                NaN
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0  Unnamed: 5_level_0  \
#                     Pos              Squad                Comp
# ...

# %%
df_std_stats, df_shooting, df_passing, df_passing_types, df_gca, df_defense, df_possession =

# %%
for i in html_files:
    print(i)
# Out:
# players_Big 5 European Leagues Combined_1718_defense.html
# players_Big 5 European Leagues Combined_1718_gca.html
# players_Big 5 European Leagues Combined_1718_keeper.html
# players_Big 5 European Leagues Combined_1718_keeper_adv.html
# players_Big 5 European Leagues Combined_1718_misc.html
# players_Big 5 European Leagues Combined_1718_passing.html
# players_Big 5 European Leagues Combined_1718_passing_types.html
# players_Big 5 European Leagues Combined_1718_playing_time.html
# players_Big 5 European Leagues Combined_1718_possession.html
# players_Big 5 European Leagues Combined_1718_shooting.html
# players_Big 5 European Leagues Combined_1819_defense.html
# players_Big 5 European Leagues Combined_1819_gca.html
# players_Big 5 European Leagues Combined_1819_keeper.html
# players_Big 5 European Leagues Combined_1819_keeper_adv.html
# players_Big 5 European Leagues Combined_1819_misc.html
# players_Big 5 European Leagues Combined_1819_passing.html
# ...

# %%
for file_path in html_files:
    df = pd.read_html(file_path)[0]
    data_frames.append(df)

# %%
fbref = sd.FBref(leagues="Big 5 European Leagues Combined", seasons=[17, 18, 19,20,21,22,23])
print(fbref.__doc__)
# Out:
# [01/07/24 20:05:37] INFO     Saving cached data to C:\Users\femi\soccerdata\data\FBref                ]8;id=441732;file://C:\Users\femi\AppData\Local\Programs\Python\Python312\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=256015;file://C:\Users\femi\AppData\Local\Programs\Python\Python312\Lib\site-packages\soccerdata\_common.py#91\91]8;;\
# Provides pd.DataFrames from data at http://fbref.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FBref``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include. For efficiently reading data from the Top-5
#         European leagues, use "Big 5 European Leagues Combined".
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
# ...

# %%
player_stats = fbref.read_player_season_stats(stat_type='shooting')
player_stats = fbref.read_player_season_stats(stat_type='passing')
player_stats = fbref.read_player_season_stats(stat_type='passing_types')
player_stats = fbref.read_player_season_stats(stat_type='goal_shot_creation')
player_stats = fbref.read_player_season_stats(stat_type='defense')
player_stats = fbref.read_player_season_stats(stat_type='possession')
player_stats = fbref.read_player_season_stats(stat_type='playing_time')
player_stats = fbref.read_player_season_stats(stat_type='misc')
player_stats = fbref.read_player_season_stats(stat_type='possession')
player_stats = fbref.read_player_season_stats(stat_type='keeper')
player_stats = fbref.read_player_season_stats(stat_type='keeper_adv')

# %%
print(len(data_frames[27]))
print(len(data_frames[26]))
print(len(data_frames[25]))

print(len(data_frames[28]))
print(len(data_frames[29]))
print(len(data_frames[30]))
# Out:
# 2934
# 2934
# 2934
# 3581
# 2934
# 2934

# %%
data_frames[28]
# Out:
#      Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                      Rk               Player             Nation
# 0                     1        Ismael Aaneba             fr FRA
# 1                     2  Patrick van Aanholt             nl NED
# 2                     3          Issah Abbas             gh GHA
# 3                     4       Basit Abdallah             gh GHA
# 4                     5     Yunis Abdelhamid             ma MAR
# ...                 ...                  ...                ...
# 3576               3440      Martin Ødegaard             no NOR
# 3577               3441      Martin Ødegaard             no NOR
# 3578               3442        Filip Đuričić             rs SRB
# 3579               3443               Blanco                NaN
# 3580               3444       Hugo Guillamón                NaN
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0  Unnamed: 5_level_0  \
#                     Pos              Squad                Comp
# ...

# %% [markdown]
# ## Exploratory Finessing
# Which just means I'm looking for how to combine these pandas

# %%
data_frames[1]
# Out:
#      Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                      Rk               Player             Nation
# 0                     1        Ismael Aaneba             fr FRA
# 1                     2  Patrick van Aanholt             nl NED
# 2                     3        Ignazio Abate             it ITA
# 3                     4          Issah Abbas             gh GHA
# 4                     5     Yunis Abdelhamid             ma MAR
# ...                 ...                  ...                ...
# 2757               2652      Ervin Zukanović             ba BIH
# 2758               2653        Bongani Zungu             za RSA
# 2759               2654       David Zurutuza             es ESP
# 2760               2655       Filip Đorđević             rs SRB
# 2761               2656        Filip Đuričić             rs SRB
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0  Unnamed: 5_level_0  \
#                     Pos              Squad                Comp
# ...

# %%
for things in range(1,11):
    print(data_frames[things].columns)
    print(data_frames[things].Player)
# Out:
# MultiIndex([( 'Unnamed: 0_level_0',      'Rk'),
#             ( 'Unnamed: 1_level_0',  'Player'),
#             ( 'Unnamed: 2_level_0',  'Nation'),
#             ( 'Unnamed: 3_level_0',     'Pos'),
#             ( 'Unnamed: 4_level_0',   'Squad'),
#             ( 'Unnamed: 5_level_0',    'Comp'),
#             ( 'Unnamed: 6_level_0',     'Age'),
#             ( 'Unnamed: 7_level_0',    'Born'),
#             ( 'Unnamed: 8_level_0',     '90s'),
#             (            'Tackles',     'Tkl'),
#             (            'Tackles',    'TklW'),
#             (            'Tackles', 'Def 3rd'),
#             (            'Tackles', 'Mid 3rd'),
#             (            'Tackles', 'Att 3rd'),
#             (         'Challenges',     'Tkl'),
#             (         'Challenges',     'Att'),
#             (         'Challenges',    'Tkl%'),
#             (         'Challenges',    'Lost'),
#             (             'Blocks',  'Blocks'),
#             (             'Blocks',      'Sh'),
# ...
