# %%
import os

directory = r'C:\Users\femi\soccerdata\data\FBref'
os.chdir(directory)

# %%
os.listdir(directory)
for filename in os.listdir(directory):
    if filename.endswith(".html"):
        print(os.path.join(directory, filename))
        continue
    else:
        continue
# Out:
# C:\Users\femi\soccerdata\data\FBref\leagues.html
# C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_defense.html
# C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_gca.html
# C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_keeper.html
# C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_keeper_adv.html
# C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_misc.html
# C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_passing.html
# C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_passing_types.html
# C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_playing_time.html
# C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_possession.html
# ...

# %%
import pandas as pd
directory = os.getcwd()  # Get the current working directory
html_files = [file for file in os.listdir(directory) if file.endswith(".html")]

data_frames = []
for file in html_files:
    file_path = os.path.join(directory, file)
    df = pd.read_html(file_path)[0]
    data_frames.append(df)
    locals()[file.split(".")[0]] = df  # Assign dataframe to a variable with the same name as the file

# Print the list of dataframes
for i, df in enumerate(data_frames):
    print(f"Dataframe {i+1}:")
    print(df)
# Out:
# Dataframe 1:
#                 Competition Name Gender Governing Body First Season  \
# 0   Copa Libertadores de América      M       CONMEBOL         2014
# 1              Copa Sudamericana      M       CONMEBOL         2014
# 2          UEFA Champions League      M           UEFA    1990-1991
# 3             UEFA Europa League      M           UEFA    1990-1991
# 4  UEFA Europa Conference League      M           UEFA    2021-2022
# 5                 UEFA Super Cup      M           UEFA         2000
# 6  UEFA Women's Champions League      F           UEFA    2014-2015
#
#   Last Season Tier
# 0        2024  1st
# 1        2024  2nd
# 2   2023-2024  1st
# 3   2023-2024  2nd
# 4   2023-2024  3rd
# 5        2023  NaN
# 6   2023-2024  1st
# Dataframe 2:
#      Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                      Rk               Player             Nation
# 0                     1        Ismael Aaneba             fr FRA
# ...

# %%
file_paths = [
    r'C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_defense.html',
    r'C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_gca.html',
    r'C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_keeper.html',
    r'C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_keeper_adv.html',
    r'C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_misc.html',
    r'C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_passing.html',
    r'C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_passing_types.html',
    r'C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_playing_time.html',
    r'C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_possession.html',
    r'C:\Users\femi\soccerdata\data\FBref\players_Big 5 European Leagues Combined_1819_shooting.html'
]

data_frames = []

for file_path in file_paths:
    df = pd.read_html(file_path)[0]
    data_frames.append(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 19
#      16 data_frames = []
#      18 for file_path in file_paths:
# ---> 19     df = pd.read_html(file_path)[0]
#      20     data_frames.append(df)
#
# File c:\Users\femi\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\html.py:1031, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1027             continue
#    1028     return ret
# -> 1031 @doc(storage_options=_shared_docs["storage_options"])
#    1032 def read_html(
#    1033     io: FilePath | ReadBuffer[str],
#    1034     *,
#    1035     match: str | Pattern = ".+",
#    1036     flavor: str | None = None,
#    1037     header: int | Sequence[int] | None = None,
# ...
